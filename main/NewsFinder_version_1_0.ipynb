# %% [markdown]
# # **NewsFinder: Advanced GenAI**

# %% [markdown]
# **Problem Statement**
#
# NewsFindr is redefining news discovery by delivering real-time news updates tailored to user interests. Traditional search methods and generic news feeds often lead to information overload and inefficiencies, making it challenging for users to access relevant and trustworthy content efficiently.
#
# To address this, NewsFindr wants to leverage Agentic AI to build an AI-powered news retrieval agent that ensures accuracy and credibility. By utilizing a structured, multi-step approach, the system will provide secure, fair, and explainable recommendations - enhancing user engagement, optimizing content discovery, and improving access to timely and relevant news.
#
#
#
# **Objective**
#
# Provide real-time, personalized news retrieval to help users discover relevant content effortlessly.
# Ensure accuracy and credibility by sourcing news from trusted platforms and minimizing misinformation.
# Improve user engagement through seamless content discovery, reducing information overload.
# Streamline the news consumption process by eliminating outdated and irrelevant content, providing a refined reading experience.

# %% [markdown]
# # Mounting Google drive

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd "/content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main

# %%
# !ls
# Out:
# Database  main.py  NewsFinder.py  NewsFinder_version_1_0.ipynb	__pycache__

# %% [markdown]
# # PACKAGE INSTALLATION

# %%
# !pip install groq
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# !pip install sqlalchemy
# !pip install sqlite3
# !pip install langchain_community
# !pip install ddgs
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (0.31.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.75)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.24)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain-groq in /usr/local/lib/python3.12/dist-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.3.75)
# Requirement already satisfied: groq<1,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.31.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.4.24)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.5.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.12/dist-packages (0.3.29)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.3.75)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: requests<3,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.24)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.125->langchain_community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.125->langchain_community) (0.24.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.5->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.5->langchain_community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: ddgs in /usr/local/lib/python3.12/dist-packages (9.5.5)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from ddgs) (6.0.1)

# %% [markdown]
# # Solution

# %% [markdown]
#         --> class NewsFinder.py
#             --> def __init__(self,base_path,groq_api)
#                 * Assigning the GroqAPI key, Model name
#                 * Load the DB from the base location
#
#             --> def Load_LLM(self,userQuery):
#                 * Loading the LLM llama-3.3-70b-versatile and testing the LLm with some test query
#
#             --> def SQLAgents(self):
#                 * Initalize the SQL Agents
#
#             --> def Verify_Customer_Email(self,emailID):
#                 * If the input user's mail id is present then it will display the interests of the customer in the db
#
#             --> def Search_News(self,interests,no_of_urls):
#                 * if the mail id of the customer is passed it will get the URLs for the customer's interests
#
#             --> def Fetch_News_URLs(self, emailIDs,no_of_urls):
#                 * Invoking the function Verify_Customer_Email and Fetch_News_URLs function
#
#             --> def Get_News_Summary(self, urls, interest):
#                 * this function will summarise the the news from the Customers Interest URLs
#
#             --> def Generate_News_Summaries(self, news_urls):
#                 * Invoking the verify email and Get News summary function

# %%
# %%writefile NewsFinder.py
import os
import traceback
import sqlite3
import warnings
import json
import re
from groq import Groq
from langchain_groq.chat_models import ChatGroq
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits.sql.base import create_sql_agent
from langchain_community.tools import DuckDuckGoSearchRun


warnings.filterwarnings("ignore",category=Warning,module="langchain.*")

class NewsFinder:
  def __init__(self,base_path,groq_api):
    self.agent = None
    self.grok_api_key = groq_api
    self.base_path = base_path
    self.sql_DB = SQLDatabase.from_uri(f"sqlite:///{os.path.join(self.base_path,"Database","customer.db")}")

    self.SystemMessage = "You are a helpful assistant to assistant designed to respond to user queries with accurate and concise information"
    self.model = "llama-3.3-70b-versatile"
    #self.model = 'llama-3.1-8b-instant'

#model="llama-3.3-70b-versatile",
  def Load_LLM(self,userQuery):
    try:
      client = Groq(api_key=self.grok_api_key)
      completion = client.chat.completions.create(
        model=self.model,
        messages=[
            {"role": "system", "content": self.SystemMessage},
            {"role": "user","content": userQuery}

        ],
        temperature = 0.1,
        max_completion_tokens=None,
        top_p=1,
        stream=True,
        stop=None )

      full_response = ""
      for chunk in completion:
        content = chunk.choices[0].delta.content or ""
        full_response += content
        print(content, end ="")
      print(f"\n Complete LLM response: {full_response}")
      return full_response
    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())

  def SQLAgents(self):
    try:

      llm_Obj = ChatGroq(api_key=self.grok_api_key,
                         model_name = self.model)

      toolkit = SQLDatabaseToolkit(db=self.sql_DB, llm=llm_Obj)

      self.agent = create_sql_agent(llm= llm_Obj,
                                    toolkit=toolkit,
                                    verbose=True)
      return self.agent

    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())

  def Get_Customer_Details(self,emailID):
    try:
      if emailID is None or not emailID.strip():
          raise ValueError("Email ID is not provided")
      if self.agent is None:
        self.SQLAgents()

      email_list = [email.strip() for email in emailID.split(',')]

      emailID_list = ", ".join(f" '{email}' " for email in email_list)
      print(emailID_list)
      query = f"SELECT * FROM customers  WHERE email IN ({emailID_list})"
      result = self.agent.run(query)
      if result is "I don't know":
        result = f"Email ID {emailID} not found in DB"
      print(f"Raw Result: {result}")
      return result
    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())

  def Verify_Customer_Email(self,emailID):
    try:
      if emailID is None or not emailID.strip():
          raise ValueError("Email ID is not provided")
      if self.agent is None:
        self.SQLAgents()

      email_list = [email.strip() for email in emailID.split(',')]

      emailID_list = ", ".join(f" '{email}' " for email in email_list)
      print(emailID_list)
      query = f"SELECT interests FROM customers WHERE email IN ({emailID_list})"
      result = self.agent.run(query)

      print(f"Raw Result: {result}")
      print(type(result))
      interests = {}
      if isinstance(result,str):
        try:
          result_patters = re.findall(r'\["[^"\]]*(?:"[^"\]]*"[^"\]]*)*"\]', result)
          for indx, interest_string in enumerate(result_patters):
            if indx < len(email_list):
              cleaned_strings = interest_string.strip('[]')
              items = re.findall(r'"([^"]*)"',cleaned_strings)
              interests[email_list[indx]] = items
        except Exception as ex:
          print(f"Exception: {ex}")
          print(traceback.print_exc())

      return interests

    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())
      return {}

  def Search_News(self,interests,no_of_urls):
    try:
      search_tool = DuckDuckGoSearchRun()

      filtered_URLS = {}

      for email,interest_list in interests.items():
        for indvidual_interest in interest_list:
          expand_query = f"latest news article on {indvidual_interest} after:2025-01-01 site:bbc.com OR site:reuters.com OR site:nytimes.com OR site:apnews.com OR site:theguardian.com"

          search_results = search_tool.run(expand_query)
          #print(f"Search Results for {interest}")

          filter_query = f"From the following search search results, extract 3-5 trustworthy news URLs(not homepage) relevant to '{indvidual_interest}' published after December 31 2024. Priortize recent, credible source like BBC, Reuters, NYT, AP, Guardian. List only the URLs: \n {search_results}"

          query_results = self.Load_LLM(filter_query)

          #print(f"Query Results: {query_results}")
          urls = re.findall(r'https?://[^\s]+',query_results)

          urls = list(dict.fromkeys(url for url in urls if url.strip().startswith("http")))

          filtered_URLS[indvidual_interest] = urls[:no_of_urls]
      #print(f"Final Filtered URLs {filtered_URLS}")
      return filtered_URLS

    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())

  def Fetch_News_URLs(self, emailIDs,no_of_urls):
    try:
      results_intersets = self.Verify_Customer_Email(emailIDs)
      news_urls = self.Search_News(results_intersets,no_of_urls)
      print(f"Filtered news URLs for {emailIDs}:{news_urls}")
      return news_urls
    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())
      return {}

  def Get_News_Summary(self, urls, interest):
    try:
      summary = f"Relevant Latest news on {interest}"

      citation_id =1
      for indx,url in enumerate(urls[:4],1):
        content_query = f"Extract a concise summary (4-5 sentence) of the latest news from {url}. focus only on key facts and relevance to {interest}. Return the response in format \n\n\n Title:[title] \n\n Key Points:[points] \n\n Source: [source] \n\n Date: [date] \n\n Summary:[summary]\n\n URL:[url]"

        summary_content = self.Load_LLM(content_query)

        summary += f"\n\n{summary_content}\n\n"

        # print(f"summary for {interest} Item {indx} {summary_content}")

      return summary
    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())
      return f"No Summary Available for {interest}"

  def Generate_News_Summaries(self, news_urls):
    try:
      news_summary = {}
      for interest, urls in news_urls.items():
        news_summary[interest] = self.Get_News_Summary(urls,interest)
        #print(f"News Summary: {news_summary}")
        return news_summary
    except Exception as ex:
      print(f"Exception: {ex}")
      print(traceback.print_exc())
# Out:
# Overwriting NewsFinder.py

# %%
# %%writefile main.py

import os
import warnings
os.environ["PYTHONWARNINGS"] = "ignore"
import sys
import argparse
from dotenv import load_dotenv

try:
  base_path = os.path.abspath((os.path.dirname(__file__)))
except:
  base_path = os.path.join(os.getcwd())

print(f"Base Path: {base_path}")
sys.path.append(base_path)
from NewsFinder import NewsFinder
parser = argparse.ArgumentParser(description="To run a specific job in pipeline")
parser.add_argument('--job', type=str, required=True,
                    choices=['test-llm','get-all-data','verify-email','get-urls','get-summary','test-agent'],
                    help='Jobs to execute')

args = parser.parse_args()

load_dotenv(dotenv_path=os.path.join(base_path,".env"))
groq_api = os.getenv('GROQ_API_KEY')
open_api = os.getenv('OPEN_API_KEY')
newFindr_Obj = NewsFinder(base_path,groq_api)

if groq_api is None:
  raise ValueError("GROQ_API_KEY not found in .env file")

if open_api is None:
  raise ValueError("OPEN_API_KEY not found in .env file")


if args.job == 'test-llm':
  userQuery = input("Enter your query:")
  newFindr_Obj.Load_LLM(userQuery)

elif args.job == 'get-all-data':
  emailID = input("Enter your email ID: ")
  result = newFindr_Obj.Get_Customer_Details(emailID)

elif args.job == 'verify-email':
  emailID = input("Enter your email ID: ")
  interset = newFindr_Obj.Verify_Customer_Email(emailID)
  print(f"interset: {interset}")

elif args.job == 'get-urls':
  newFindr_Obj.SQLAgents()
  emailID = input("Enter your Email ID")
  no_of_urls = int(input("Enter the number of URLs required"))
  news_urls = newFindr_Obj.Fetch_News_URLs(emailID,no_of_urls)
  print(f"News URLs: {news_urls}")

elif args.job == 'get-summary':
  newFindr_Obj.SQLAgents()
  emailID = input("Enter your Email ID")
  no_of_urls = int(input("Enter the number of URLs required"))
  news_urls = newFindr_Obj.Fetch_News_URLs(emailID,no_of_urls)
  news_summary = newFindr_Obj.Generate_News_Summaries(news_urls)
  for interest, summary in news_summary.items():
    print('-'*50)
    print(f"Summary for {interest}:\n\n {summary}")

elif args.job == 'test-agent':
  newFindr_Obj.SQLAgents()
  query = input(f"Enter the query:")
  print(f"Query: {query}")
  result = newFindr_Obj.agent.run(query)
  print(f"Result: {result}")
  print('-'*50)
# Out:
# Overwriting main.py

# %% [markdown]
# # Question ##01 Load LLM and test with simple query

# %%
# !python main.py --job test-llm
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your query:What is RAG in GenAI ? list out all its types
# In GenAI (General Artificial Intelligence), RAG stands for "Retrieval-Augmented Generation". It's a technique used in natural language processing (NLP) and language models to improve the accuracy and relevance of generated text.
#
# RAG involves two main components:
#
# 1. **Retrieval**: This component is responsible for searching and retrieving relevant information from a large database or knowledge base.
# 2. **Generation**: This component uses the retrieved information to generate text that is contextually relevant and accurate.
#
# There are several types of RAG models, including:
#
# 1. **RAG-T5**: This is a type of RAG model that uses the T5 (Text-to-Text Transfer Transformer) architecture. It's a popular model that has achieved state-of-the-art results in various NLP tasks.
# 2. **RAG-Seq2Seq**: This type of RAG model uses a sequence-to-sequence (Seq2Seq) architecture, which is commonly used in machine translation and text summarization tasks.
# 3. **RAG-Transformer**: This type of RAG model uses a transformer-based architecture, which is known for its ability to handle long-range dependencies in text data.
# 4. **RAG-BERT**: This type of RAG model uses the BERT (Bidirectional Encoder Representations from Transformers) architecture, which is a pre-trained language model that has achieved state-of-the-art results in various NLP tasks.
# 5. **RAG-DPR**: This type of RAG model uses the DPR (Dense Passage Retriever) architecture, which is a neural network-based retrieval model that is designed to retrieve relevant passages from a large corpus of text.
# 6. **RAG-EM**: This type of RAG model uses an Expectation-Maximization (EM) algorithm to iteratively refine the retrieval and generation components.
# 7. **RAG-RL**: This type of RAG model uses reinforcement learning (RL) to optimize the retrieval and generation components.
# 8. **RAG-Hybrid**: This type of RAG model combines multiple retrieval and generation models to achieve better performance.
#
# These are some of the main types of RAG models, but it's worth noting that new variants and architectures are being developed and researched continuously.
#
# Each type of RAG model has its strengths and weaknesses, and the choice of which one to use depends on the specific application, dataset, and performance metrics.
#  Complete LLM response: In GenAI (General Artificial Intelligence), RAG stands for "Retrieval-Augmented Generation". It's a technique used in natural language processing (NLP) and language models to improve the accuracy and relevance of generated text.
#
# RAG involves two main components:
#
# 1. **Retrieval**: This component is responsible for searching and retrieving relevant information from a large database or knowledge base.
# 2. **Generation**: This component uses the retrieved information to generate text that is contextually relevant and accurate.
#
# There are several types of RAG models, including:
#
# 1. **RAG-T5**: This is a type of RAG model that uses the T5 (Text-to-Text Transfer Transformer) architecture. It's a popular model that has achieved state-of-the-art results in various NLP tasks.
# 2. **RAG-Seq2Seq**: This type of RAG model uses a sequence-to-sequence (Seq2Seq) architecture, which is commonly used in machine translation and text summarization tasks.
# 3. **RAG-Transformer**: This type of RAG model uses a transformer-based architecture, which is known for its ability to handle long-range dependencies in text data.
# 4. **RAG-BERT**: This type of RAG model uses the BERT (Bidirectional Encoder Representations from Transformers) architecture, which is a pre-trained language model that has achieved state-of-the-art results in various NLP tasks.
# 5. **RAG-DPR**: This type of RAG model uses the DPR (Dense Passage Retriever) architecture, which is a neural network-based retrieval model that is designed to retrieve relevant passages from a large corpus of text.
# 6. **RAG-EM**: This type of RAG model uses an Expectation-Maximization (EM) algorithm to iteratively refine the retrieval and generation components.
# 7. **RAG-RL**: This type of RAG model uses reinforcement learning (RL) to optimize the retrieval and generation components.
# 8. **RAG-Hybrid**: This type of RAG model combines multiple retrieval and generation models to achieve better performance.
#
# These are some of the main types of RAG models, but it's worth noting that new variants and architectures are being developed and researched continuously.
#
# Each type of RAG model has its strengths and weaknesses, and the choice of which one to use depends on the specific application, dataset, and performance metrics.

# %% [markdown]
# # Question Verify the customer's email and retrieve their details

# %% [markdown]
# ## for valid email

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-all-data
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your email ID: george.5483cb53-8@gmail.com
#  'george.5483cb53-8@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersI have the list of tables in the database, which is just "customers". I should now query the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */I have the schema of the "customers" table, which includes columns such as "id", "customer_id", "name", "email", "interests", and "last_updated". The question seems to be asking for a specific customer based on their email. However, the original query provided is not the question, but rather a query itself. I should rephrase the question to "What are the details of the customer with the email 'george.5483cb53-8@gmail.com'?".
#
# Action: sql_db_query_checker
# Action Input: SELECT * FROM customers WHERE email IN ( 'george.5483cb53-8@gmail.com' )```sql
# SELECT * FROM customers WHERE email = 'george.5483cb53-8@gmail.com'
# ```The query checker suggests a slight modification to the query, replacing `IN` with `=`, as we're only checking for a single email.
#
# Action: sql_db_query
# Action Input: SELECT * FROM customers WHERE email = 'george.5483cb53-8@gmail.com'[(7, '5483CB53-8', 'George', 'george.5483cb53-8@gmail.com', '["India", "Politics", "Science"]', '2025-03-26 06:46:15')]I now know the final answer
#
# Final Answer: The customer with the email 'george.5483cb53-8@gmail.com' has the following details: id = 7, customer_id = '5483CB53-8', name = 'George', interests = '["India", "Politics", "Science"]', and last_updated = '2025-03-26 06:46:15'.
#
# > Finished chain.
# Raw Result: The customer with the email 'george.5483cb53-8@gmail.com' has the following details: id = 7, customer_id = '5483CB53-8', name = 'George', interests = '["India", "Politics", "Science"]', and last_updated = '2025-03-26 06:46:15'.

# %% [markdown]
# ## For Invalid Email

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-all-data
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:86: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if result is "I don't know":
# Enter your email ID: karthik@abc.com
#  'karthik@abc.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersI have the list of tables in the database, and I see that the "customers" table is present. Now, I should check the schema of the "customers" table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */I have the schema of the "customers" table, and I see that it has columns for id, customer_id, name, email, interests, and last_updated. The question asks for all columns from the customers table where the email is 'karthik@abc.com'. However, since I should never query for all the columns from a specific table, I will only ask for the relevant columns. In this case, I will ask for the name and email columns.
#
# Action: sql_db_query_checker
# Action Input: SELECT name, email FROM customers WHERE email IN ('karthik@abc.com')```sql
# SELECT name, email
# FROM customers
# WHERE email = 'karthik@abc.com'
# ```The query checker corrected my query to use '=' instead of 'IN' since I'm only checking for a single email.
#
# Action: sql_db_query
# Action Input: SELECT name, email FROM customers WHERE email = 'karthik@abc.com'Observation: No results were returned, indicating that there is no customer with the email 'karthik@abc.com' in the database.
#
# Thought: I now know the final answer
#
# Final Answer: There is no customer with the email 'karthik@abc.com' in the database.
#
# > Finished chain.
# Raw Result: There is no customer with the email 'karthik@abc.com' in the database.

# %% [markdown]
# # To get the user Interest for single Email ID

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job verify-email
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your email ID: ian.203631a0-b@gmail.com
#  'ian.203631a0-b@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:104: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersI have the list of tables in the database, and I see that the "customers" table is one of them. Now, I should check the schema of the "customers" table to see what columns it has.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */I have the schema of the "customers" table, and I see that it has a column named "interests" and a column named "email". The question is asking for the "interests" of a customer with a specific email. I can construct a SQL query to get this information.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'ian.203631a0-b@gmail.com' )```sql
# SELECT interests
# FROM customers
# WHERE email = 'ian.203631a0-b@gmail.com'
# ```The query checker suggests a slight modification to the query, removing the IN operator since we're only checking for a single email.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'ian.203631a0-b@gmail.com'[('["Startups", "Travel"]',)]I now know the final answer
# Final Answer: ["Startups", "Travel"]
#
# > Finished chain.
# Raw Result: ["Startups", "Travel"]
# <class 'str'>
# interset: {'ian.203631a0-b@gmail.com': ['Startups', 'Travel']}

# %% [markdown]
# # To get the user Interest for Multiple Email ID

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job verify-email
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your email ID: ian.203631a0-b@gmail.com,julia.d77d96f3-3@gmail.com
#  'ian.203631a0-b@gmail.com' ,  'julia.d77d96f3-3@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersSince the observation only returned one table, "customers", I will query the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */With the schema of the "customers" table, I can see that the column name is actually "interests", not "interset". I also notice that the email addresses in the question match the ones in the sample rows.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'ian.203631a0-b@gmail.com' ,  'julia.d77d96f3-3@gmail.com' )```sql
# SELECT interests
# FROM customers
# WHERE email IN ('ian.203631a0-b@gmail.com', 'julia.d77d96f3-3@gmail.com')
# ```The query looks correct, I will now execute it.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email IN ( 'ian.203631a0-b@gmail.com' ,  'julia.d77d96f3-3@gmail.com' )[('["Startups", "Travel"]',), ('["India", "Automobile", "Business"]',)]I now know the final answer
# Final Answer: Ian's interests are ["Startups", "Travel"] and Julia's interests are ["India", "Automobile", "Business"].
#
# > Finished chain.
# Raw Result: Ian's interests are ["Startups", "Travel"] and Julia's interests are ["India", "Automobile", "Business"].
# <class 'str'>
# interset: {'ian.203631a0-b@gmail.com': ['Startups', 'Travel'], 'julia.d77d96f3-3@gmail.com': ['India', 'Automobile', 'Business']}

# %% [markdown]
# # Interface between SQL and Search Agents

# %% [markdown]
# ## To get the News URLs for the customers interest from DuckDuckGo based on the input email id given by the agent

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-urls
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDnora.c63fa237-e@gmail.com
# Enter the number of URLs required1
#  'nora.c63fa237-e@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersNow that I have the list of tables, I can see that there is a "customers" table. However, the question mentions a "users" table and an "email" column, which doesn't seem to match the "customers" table. I should query the schema of the "customers" table to see if it has any relevant columns.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */The "customers" table seems to have an "email" column, but the column name in the question is "interset" which doesn't seem to match any column in the "customers" table. However, there is an "interests" column which could be what the question is referring to. I should rewrite the query to use the correct table and column names.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'nora.c63fa237-e@gmail.com' )SELECT interests FROM customers WHERE email IN ( 'nora.c63fa237-e@gmail.com' )The query seems to be correct. I should now execute it to get the results.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email IN ( 'nora.c63fa237-e@gmail.com' )[('["Entertainment", "Business"]',)]I now know the final answer
# Final Answer: ["Entertainment", "Business"]
#
# > Finished chain.
# Raw Result: ["Entertainment", "Business"]
# <class 'str'>
# Here are 3-5 trustworthy news URLs relevant to 'Entertainment' published after December 31, 2024:
#
# * https://apnews.com/article/entertainment-music-lady-gaga-taylor-swift-mtv-video-music-awards-36b7e4447ec7b4e89fCAA
# * https://www.bbc.com/news/entertainment-arts-65321568
# * https://www.reuters.com/lifestyle/entertainment-arts/strictly-come-dancing-2025-celebrity-contestants-confirmed-2025-08-21
# * https://www.nytimes.com/2025/08/22/arts/music/best-music-of-the-year.html
# * https://www.theguardian.com/tv-and-radio/2025/aug/21/strictly-come-dancing-2025-lineup-revealed
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Entertainment' published after December 31, 2024:
#
# * https://apnews.com/article/entertainment-music-lady-gaga-taylor-swift-mtv-video-music-awards-36b7e4447ec7b4e89fCAA
# * https://www.bbc.com/news/entertainment-arts-65321568
# * https://www.reuters.com/lifestyle/entertainment-arts/strictly-come-dancing-2025-celebrity-contestants-confirmed-2025-08-21
# * https://www.nytimes.com/2025/08/22/arts/music/best-music-of-the-year.html
# * https://www.theguardian.com/tv-and-radio/2025/aug/21/strictly-come-dancing-2025-lineup-revealed
# Here are 3-5 trustworthy news URLs relevant to 'Business' (note: since the search results do not provide specific URLs, I will provide general URLs from credible sources that may have business news published after December 31, 2024):
#
# * https://www.nytimes.com/section/business
# * https://apnews.com/hub/business
# * https://www.reuters.com/business
# * https://www.theguardian.com/business
# * https://www.bbc.com/news/business
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Business' (note: since the search results do not provide specific URLs, I will provide general URLs from credible sources that may have business news published after December 31, 2024):
#
# * https://www.nytimes.com/section/business
# * https://apnews.com/hub/business
# * https://www.reuters.com/business
# * https://www.theguardian.com/business
# * https://www.bbc.com/news/business
# Filtered news URLs for nora.c63fa237-e@gmail.com:{'Entertainment': ['https://apnews.com/article/entertainment-music-lady-gaga-taylor-swift-mtv-video-music-awards-36b7e4447ec7b4e89fCAA'], 'Business': ['https://www.nytimes.com/section/business']}
# News URLs: {'Entertainment': ['https://apnews.com/article/entertainment-music-lady-gaga-taylor-swift-mtv-video-music-awards-36b7e4447ec7b4e89fCAA'], 'Business': ['https://www.nytimes.com/section/business']}

# %% [markdown]
# # Output from LLMs

# %% [markdown]
# ## Retrieve the final URL(s) for the latest news based on the customer’s interest and  Create a summary of the retrieved links

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-summary
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDgeorge.5483cb53-8@gmail.com
# Enter the number of URLs required1
#  'george.5483cb53-8@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersThere is only one table in the database, which is 'customers'. I should query the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */The user's question seems to be related to the database, but it's not a standard SQL query. The user is asking to "SELECT interset FROM users WHERE email IN ( 'george.5483cb53-8@gmail.com' )", but there is no "users" table in the database, and the column name "interset" is likely a typo, as the "customers" table has a column named "interests".
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'george.5483cb53-8@gmail.com' )```sql
# SELECT interests
# FROM customers
# WHERE email = 'george.5483cb53-8@gmail.com'
# ```The query checker suggests a corrected query. I should use this query to get the results from the database.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'george.5483cb53-8@gmail.com'[('["India", "Politics", "Science"]',)]I now know the final answer
# Final Answer: ["India", "Politics", "Science"]
#
# > Finished chain.
# Raw Result: ["India", "Politics", "Science"]
# <class 'str'>
# Here are 3-5 trustworthy news URLs relevant to 'India' published after December 31, 2024:
#
# * https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9 (Sep 3, 2025)
# * https://www.reuters.com/article/us-india-tax-cuts-idUSKBN2ZL0ER (Sep 3, 2025)
# * https://www.reuters.com/article/us-india-floods-idUSKBN2ZN0ER (Sep 4, 2025)
# * https://www.reuters.com/article/us-usa-india-tariffs-idUSKBN2ZL0ET (Sep 4, 2025)
# * https://www.reuters.com/article/us-india-usa-relations-idUSKBN2ZK0ES (Sep 1, 2025)
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'India' published after December 31, 2024:
#
# * https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9 (Sep 3, 2025)
# * https://www.reuters.com/article/us-india-tax-cuts-idUSKBN2ZL0ER (Sep 3, 2025)
# * https://www.reuters.com/article/us-india-floods-idUSKBN2ZN0ER (Sep 4, 2025)
# * https://www.reuters.com/article/us-usa-india-tariffs-idUSKBN2ZL0ET (Sep 4, 2025)
# * https://www.reuters.com/article/us-india-usa-relations-idUSKBN2ZK0ES (Sep 1, 2025)
# Unfortunately, there are no specific news URLs provided in the search results. However, based on the text, here are 3-5 trustworthy news URLs that may be relevant to 'Politics' (note: these are not actual search results, but rather examples of what the URLs might look like):
#
# * https://apnews.com/article/us-politics-government
# * https://www.nytimes.com/section/us/politics
# * https://www.reuters.com/news/us-politics
# * https://www.bbc.com/news/us-election-2025
# * https://www.theguardian.com/us-news/us-politics
#  Complete LLM response: Unfortunately, there are no specific news URLs provided in the search results. However, based on the text, here are 3-5 trustworthy news URLs that may be relevant to 'Politics' (note: these are not actual search results, but rather examples of what the URLs might look like):
#
# * https://apnews.com/article/us-politics-government
# * https://www.nytimes.com/section/us/politics
# * https://www.reuters.com/news/us-politics
# * https://www.bbc.com/news/us-election-2025
# * https://www.theguardian.com/us-news/us-politics
# Here are 3-5 trustworthy news URLs relevant to 'Science' published after December 31, 2024:
#
# * https://www.bbc.com/news/science (not available, no specific article URL)
# * https://www.reuters.com/science (not available, no specific article URL)
# * https://www.nytimes.com/2025/09/03/opinion/china-us-science-technology.html
# * https://www.bbc.com/news/science-65452111 (not available, no specific article URL, but "US energy chief tells BBC nuclear fusion will soon power the world" is likely on this page)
# * https://www.theguardian.com/science (not available, no specific article URL)
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Science' published after December 31, 2024:
#
# * https://www.bbc.com/news/science (not available, no specific article URL)
# * https://www.reuters.com/science (not available, no specific article URL)
# * https://www.nytimes.com/2025/09/03/opinion/china-us-science-technology.html
# * https://www.bbc.com/news/science-65452111 (not available, no specific article URL, but "US energy chief tells BBC nuclear fusion will soon power the world" is likely on this page)
# * https://www.theguardian.com/science (not available, no specific article URL)
# Filtered news URLs for george.5483cb53-8@gmail.com:{'India': ['https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9'], 'Politics': ['https://apnews.com/article/us-politics-government'], 'Science': ['https://www.bbc.com/news/science']}
# Title: India's Budget Announcement
# Key Points: India's government has announced its budget for the fiscal year, focusing on growth, infrastructure development, and social welfare. The budget aims to boost economic growth, create jobs, and increase investments in key sectors. Key allocations include investments in railways, roads, and renewable energy. The budget also includes measures to support farmers, women, and marginalized communities.
# Source: Reuters
# Date: February 1, 2023
# Summary: The Indian government's latest budget announcement prioritizes economic growth, infrastructure development, and social welfare, with a focus on creating jobs, boosting investments, and supporting vulnerable populations.
# URL: https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9
#  Complete LLM response: Title: India's Budget Announcement
# Key Points: India's government has announced its budget for the fiscal year, focusing on growth, infrastructure development, and social welfare. The budget aims to boost economic growth, create jobs, and increase investments in key sectors. Key allocations include investments in railways, roads, and renewable energy. The budget also includes measures to support farmers, women, and marginalized communities.
# Source: Reuters
# Date: February 1, 2023
# Summary: The Indian government's latest budget announcement prioritizes economic growth, infrastructure development, and social welfare, with a focus on creating jobs, boosting investments, and supporting vulnerable populations.
# URL: https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9
# Summary for India:
#  Relevant Latest news on India
#
# Title: India's Budget Announcement
# Key Points: India's government has announced its budget for the fiscal year, focusing on growth, infrastructure development, and social welfare. The budget aims to boost economic growth, create jobs, and increase investments in key sectors. Key allocations include investments in railways, roads, and renewable energy. The budget also includes measures to support farmers, women, and marginalized communities.
# Source: Reuters
# Date: February 1, 2023
# Summary: The Indian government's latest budget announcement prioritizes economic growth, infrastructure development, and social welfare, with a focus on creating jobs, boosting investments, and supporting vulnerable populations.
# URL: https://www.reuters.com/article/us-india-budget-idUSKBN2ZM0G9

# %% [markdown]
# # Querying with the Agent

# %% [markdown]
# ## Provide any 3 queries to the agentic AI system

# %% [markdown]
# ### Query#01  Get all the records from the table from the customer table

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job test-agent
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter the query:get the all records from the customer db table and provide the record result in new row
# Query: get the all records from the customer db table and provide the record result in new row
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/main.py:63: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = newFindr_Obj.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersIt seems like there is a table named "customers" which is likely the table I need to query. I should now check the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */I have the schema of the "customers" table, which includes columns such as id, customer_id, name, email, interests, and last_updated. To get all records from the customers table, I should create a query that selects all relevant columns from this table.
#
# Action: sql_db_query_checker
# Action Input: SELECT id, customer_id, name, email, interests, last_updated FROM customers```sql
# SELECT id, customer_id, name, email, interests, last_updated
# FROM customers;
# ```My query seems to be correct. Now I can execute it to get the results.
#
# Action: sql_db_query
# Action Input: SELECT id, customer_id, name, email, interests, last_updated FROM customers[(1, 'F8641860-7', 'Kevin', 'kevin.f8641860-7@gmail.com', '["Politics", "Startups", "Travel"]', '2025-03-26 06:46:15'), (2, '203631A0-B', 'Ian', 'ian.203631a0-b@gmail.com', '["Startups", "Travel"]', '2025-03-26 06:46:15'), (3, 'D77D96F3-3', 'Julia', 'julia.d77d96f3-3@gmail.com', '["India", "Automobile", "Business"]', '2025-03-26 06:46:15'), (4, '6EB33C45-5', 'Alice', 'alice.6eb33c45-5@gmail.com', '["Politics", "Technology", "Business"]', '2025-03-26 06:46:15'), (5, 'EDD38E10-6', 'Oscar', 'oscar.edd38e10-6@gmail.com', '["Automobile", "India", "Sports"]', '2025-03-26 06:46:15'), (6, '4770B814-2', 'Hannah', 'hannah.4770b814-2@gmail.com', '["Entertainment", "Business", "Technology"]', '2025-03-26 06:46:15'), (7, '5483CB53-8', 'George', 'george.5483cb53-8@gmail.com', '["India", "Politics", "Science"]', '2025-03-26 06:46:15'), (8, 'FA8FE05B-7', 'Lily', 'lily.fa8fe05b-7@gmail.com', '["India", "Science"]', '2025-03-26 06:46:15'), (9, 'C63FA237-E', 'Nora', 'nora.c63fa237-e@gmail.com', '["Entertainment", "Business"]', '2025-03-26 06:46:15'), (10, '45E01919-0', 'Lily', 'lily.45e01919-0@gmail.com', '["India", "India", "Politics"]', '2025-03-26 06:46:15'), (11, 'B5A14512-C', 'Julia', 'julia.b5a14512-c@gmail.com', '["India", "Entertainment"]', '2025-03-26 06:46:15'), (12, 'A88FEC03-C', 'Emma', 'emma.a88fec03-c@gmail.com', '["Technology", "Automobile"]', '2025-03-26 06:46:15'), (13, 'AEE37571-7', 'Ian', 'ian.aee37571-7@gmail.com', '["Entertainment", "Automobile", "Startups"]', '2025-03-26 06:46:15'), (14, 'CF4D1EDB-9', 'Julia', 'julia.cf4d1edb-9@gmail.com', '["Sports", "Entertainment", "International"]', '2025-03-26 06:46:15'), (15, 'D56E53B6-1', 'Alice', 'alice.d56e53b6-1@gmail.com', '["International", "Technology"]', '2025-03-26 06:46:15')]I now know the final answer
#
# The final answer is:
#
# 1. id: 1, customer_id: F8641860-7, name: Kevin, email: kevin.f8641860-7@gmail.com, interests: ["Politics", "Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 2. id: 2, customer_id: 203631A0-B, name: Ian, email: ian.203631a0-b@gmail.com, interests: ["Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 3. id: 3, customer_id: D77D96F3-3, name: Julia, email: julia.d77d96f3-3@gmail.com, interests: ["India", "Automobile", "Business"], last_updated: 2025-03-26 06:46:15
# 4. id: 4, customer_id: 6EB33C45-5, name: Alice, email: alice.6eb33c45-5@gmail.com, interests: ["Politics", "Technology", "Business"], last_updated: 2025-03-26 06:46:15
# 5. id: 5, customer_id: EDD38E10-6, name: Oscar, email: oscar.edd38e10-6@gmail.com, interests: ["Automobile", "India", "Sports"], last_updated: 2025-03-26 06:46:15
# 6. id: 6, customer_id: 4770B814-2, name: Hannah, email: hannah.4770b814-2@gmail.com, interests: ["Entertainment", "Business", "Technology"], last_updated: 2025-03-26 06:46:15
# 7. id: 7, customer_id: 5483CB53-8, name: George, email: george.5483cb53-8@gmail.com, interests: ["India", "Politics", "Science"], last_updated: 2025-03-26 06:46:15
# 8. id: 8, customer_id: FA8FE05B-7, name: Lily, email: lily.fa8fe05b-7@gmail.com, interests: ["India", "Science"], last_updated: 2025-03-26 06:46:15
# 9. id: 9, customer_id: C63FA237-E, name: Nora, email: nora.c63fa237-e@gmail.com, interests: ["Entertainment", "Business"], last_updated: 2025-03-26 06:46:15
# 10. id: 10, customer_id: 45E01919-0, name: Lily, email: lily.45e01919-0@gmail.com, interests: ["India", "India", "Politics"], last_updated: 2025-03-26 06:46:15
# 11. id: 11, customer_id: B5A14512-C, name: Julia, email: julia.b5a14512-c@gmail.com, interests: ["India", "Entertainment"], last_updated: 2025-03-26 06:46:15
# 12. id: 12, customer_id: A88FEC03-C, name: Emma, email: emma.a88fec03-c@gmail.com, interests: ["Technology", "Automobile"], last_updated: 2025-03-26 06:46:15
# 13. id: 13, customer_id: AEE37571-7, name: Ian, email: ian.aee37571-7@gmail.com, interests: ["Entertainment", "Automobile", "Startups"], last_updated: 2025-03-26 06:46:15
# 14. id: 14, customer_id: CF4D1EDB-9, name: Julia, email: julia.cf4d1edb-9@gmail.com, interests: ["Sports", "Entertainment", "International"], last_updated: 2025-03-26 06:46:15
# 15. id: 15, customer_id: D56E53B6-1, name: Alice, email: alice.d56e53b6-1@gmail.com, interests: ["International", "Technology"], last_updated: 2025-03-26 06:46:15
#
# Note: There are more than 10 results, but the problem statement asks to limit the query to at most 10 results if not specified. In this case, I should have added a LIMIT clause to the SQL query to limit the results to 10.
#
# The corrected query should be:
# SELECT id, customer_id, name, email, interests, last_updated FROM customers LIMIT 10;
#
# The corrected final answer is:
#
# 1. id: 1, customer_id: F8641860-7, name: Kevin, email: kevin.f8641860-7@gmail.com, interests: ["Politics", "Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 2. id: 2, customer_id: 203631A0-B, name: Ian, email: ian.203631a0-b@gmail.com, interests: ["Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 3. id: 3, customer_id: D77D96F3-3, name: Julia, email: julia.d77d96f3-3@gmail.com, interests: ["India", "Automobile", "Business"], last_updated: 2025-03-26 06:46:15
# 4. id: 4, customer_id: 6EB33C45-5, name: Alice, email: alice.6eb33c45-5@gmail.com, interests: ["Politics", "Technology", "Business"], last_updated: 2025-03-26 06:46:15
# 5. id: 5, customer_id: EDD38E10-6, name: Oscar, email: oscar.edd38e10-6@gmail.com, interests: ["Automobile", "India", "Sports"], last_updated: 2025-03-26 06:46:15
# 6. id: 6, customer_id: 4770B814-2, name: Hannah, email: hannah.4770b814-2@gmail.com, interests: ["Entertainment", "Business", "Technology"], last_updated: 2025-03-26 06:46:15
# 7. id: 7, customer_id: 5483CB53-8, name: George, email: george.5483cb53-8@gmail.com, interests: ["India", "Politics", "Science"], last_updated: 2025-03-26 06:46:15
# 8. id: 8, customer_id: FA8FE05B-7, name: Lily, email: lily.fa8fe05b-7@gmail.com, interests: ["India", "Science"], last_updated: 2025-03-26 06:46:15
# 9. id: 9, customer_id: C63FA237-E, name: Nora, email: nora.c63fa237-e@gmail.com, interests: ["Entertainment", "Business"], last_updated: 2025-03-26 06:46:15
# 10. id: 10, customer_id: 45E01919-0, name: Lily, email: lily.45e01919-0@gmail.com, interests: ["India", "India", "Politics"], last_updated: 2025-03-26 06:46:15
#
# Final Answer:
# 1. id: 1, customer_id: F8641860-7, name: Kevin, email: kevin.f8641860-7@gmail.com, interests: ["Politics", "Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 2. id: 2, customer_id: 203631A0-B, name: Ian, email: ian.203631a0-b@gmail.com, interests: ["Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 3. id: 3, customer_id: D77D96F3-3, name: Julia, email: julia.d77d96f3-3@gmail.com, interests: ["India", "Automobile", "Business"], last_updated: 2025-03-26 06:46:15
# 4. id: 4, customer_id: 6EB33C45-5, name: Alice, email: alice.6eb33c45-5@gmail.com, interests: ["Politics", "Technology", "Business"], last_updated: 2025-03-26 06:46:15
# 5. id: 5, customer_id: EDD38E10-6, name: Oscar, email: oscar.edd38e10-6@gmail.com, interests: ["Automobile", "India", "Sports"], last_updated: 2025-03-26 06:46:15
# 6. id: 6, customer_id: 4770B814-2, name: Hannah, email: hannah.4770b814-2@gmail.com, interests: ["Entertainment", "Business", "Technology"], last_updated: 2025-03-26 06:46:15
# 7. id: 7, customer_id: 5483CB53-8, name: George, email: george.5483cb53-8@gmail.com, interests: ["India", "Politics", "Science"], last_updated: 2025-03-26 06:46:15
# 8. id: 8, customer_id: FA8FE05B-7, name: Lily, email: lily.fa8fe05b-7@gmail.com, interests: ["India", "Science"], last_updated: 2025-03-26 06:46:15
# 9. id: 9, customer_id: C63FA237-E, name: Nora, email: nora.c63fa237-e@gmail.com, interests: ["Entertainment", "Business"], last_updated: 2025-03-26 06:46:15
# 10. id: 10, customer_id: 45E01919-0, name: Lily, email: lily.45e01919-0@gmail.com, interests: ["India", "India", "Politics"], last_updated: 2025-03-26 06:46:15
#
# > Finished chain.
# Result: 1. id: 1, customer_id: F8641860-7, name: Kevin, email: kevin.f8641860-7@gmail.com, interests: ["Politics", "Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 2. id: 2, customer_id: 203631A0-B, name: Ian, email: ian.203631a0-b@gmail.com, interests: ["Startups", "Travel"], last_updated: 2025-03-26 06:46:15
# 3. id: 3, customer_id: D77D96F3-3, name: Julia, email: julia.d77d96f3-3@gmail.com, interests: ["India", "Automobile", "Business"], last_updated: 2025-03-26 06:46:15
# 4. id: 4, customer_id: 6EB33C45-5, name: Alice, email: alice.6eb33c45-5@gmail.com, interests: ["Politics", "Technology", "Business"], last_updated: 2025-03-26 06:46:15
# 5. id: 5, customer_id: EDD38E10-6, name: Oscar, email: oscar.edd38e10-6@gmail.com, interests: ["Automobile", "India", "Sports"], last_updated: 2025-03-26 06:46:15
# 6. id: 6, customer_id: 4770B814-2, name: Hannah, email: hannah.4770b814-2@gmail.com, interests: ["Entertainment", "Business", "Technology"], last_updated: 2025-03-26 06:46:15
# 7. id: 7, customer_id: 5483CB53-8, name: George, email: george.5483cb53-8@gmail.com, interests: ["India", "Politics", "Science"], last_updated: 2025-03-26 06:46:15
# 8. id: 8, customer_id: FA8FE05B-7, name: Lily, email: lily.fa8fe05b-7@gmail.com, interests: ["India", "Science"], last_updated: 2025-03-26 06:46:15
# 9. id: 9, customer_id: C63FA237-E, name: Nora, email: nora.c63fa237-e@gmail.com, interests: ["Entertainment", "Business"], last_updated: 2025-03-26 06:46:15
# 10. id: 10, customer_id: 45E01919-0, name: Lily, email: lily.45e01919-0@gmail.com, interests: ["India", "India", "Politics"], last_updated: 2025-03-26 06:46:15
# --------------------------------------------------

# %% [markdown]
# ### Query#02  List out the customers who have the interest in Politics

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job test-agent
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter the query:List out the customers who have the interest in Politics and provide the record result in new rows display only the name and interests
# Query: List out the customers who have the interest in Politics and provide the record result in new rows display only the name and interests
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/main.py:63: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = newFindr_Obj.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersNow that I have a list of tables, I can query the schema of the most relevant table, which appears to be "customers". This will allow me to understand the columns available in this table and construct a query to retrieve the required information.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */Now that I have the schema of the "customers" table, I can see that the "interests" column is a text field that contains a list of interests for each customer. To find the customers who have an interest in "Politics", I can use a SQL query with a WHERE clause to filter the results. Since the "interests" column contains a list, I will use the LIKE operator to search for the string "Politics" within the list.
#
# Action: sql_db_query_checker
# Action Input: SELECT name, interests FROM customers WHERE interests LIKE '%Politics%' LIMIT 10```sql
# SELECT name, interests
# FROM customers
# WHERE interests LIKE '%Politics%'
# LIMIT 10;
# ```The query looks correct. I will now execute it.
#
# Action: sql_db_query
# Action Input: SELECT name, interests FROM customers WHERE interests LIKE '%Politics%' LIMIT 10[('Kevin', '["Politics", "Startups", "Travel"]'), ('Alice', '["Politics", "Technology", "Business"]'), ('George', '["India", "Politics", "Science"]'), ('Lily', '["India", "India", "Politics"]')]I now know the final answer
#
# Final Answer: The customers who have an interest in Politics are:
# 1. Kevin - ["Politics", "Startups", "Travel"]
# 2. Alice - ["Politics", "Technology", "Business"]
# 3. George - ["India", "Politics", "Science"]
# 4. Lily - ["India", "India", "Politics"]
#
# > Finished chain.
# Result: The customers who have an interest in Politics are:
# 1. Kevin - ["Politics", "Startups", "Travel"]
# 2. Alice - ["Politics", "Technology", "Business"]
# 3. George - ["India", "Politics", "Science"]
# 4. Lily - ["India", "India", "Politics"]
# --------------------------------------------------

# %% [markdown]
# ### Query#03 when was the Ian,Hannah and Oscar records was last updated

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job test-agent
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter the query:when was the Ian,Hannah and Oscar records was last updated and provide the result records in new rows display all columns
# Query: when was the Ian,Hannah and Oscar records was last updated and provide the result records in new rows display all columns
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/main.py:63: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = newFindr_Obj.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersNow that I have the list of tables, I can query the schema of the 'customers' table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */To answer the question, I need to query the 'customers' table for the records of Ian, Hannah, and Oscar, and display all columns. However, I should first check if these records exist in the table.
#
# Action: sql_db_query_checker
# Action Input: SELECT * FROM customers WHERE name IN ('Ian', 'Hannah', 'Oscar')SELECT * FROM customers WHERE name IN ('Ian', 'Hannah', 'Oscar')Since the query checker didn't return an error, I can proceed with executing the query.
#
# Action: sql_db_query
# Action Input: SELECT * FROM customers WHERE name IN ('Ian', 'Hannah', 'Oscar')[(2, '203631A0-B', 'Ian', 'ian.203631a0-b@gmail.com', '["Startups", "Travel"]', '2025-03-26 06:46:15'), (5, 'EDD38E10-6', 'Oscar', 'oscar.edd38e10-6@gmail.com', '["Automobile", "India", "Sports"]', '2025-03-26 06:46:15'), (6, '4770B814-2', 'Hannah', 'hannah.4770b814-2@gmail.com', '["Entertainment", "Business", "Technology"]', '2025-03-26 06:46:15'), (13, 'AEE37571-7', 'Ian', 'ian.aee37571-7@gmail.com', '["Entertainment", "Automobile", "Startups"]', '2025-03-26 06:46:15')]I now know the final answer
#
# The records for Ian, Hannah, and Oscar are:
#
# 1. Ian:
# id: 2,
# customer_id: 203631A0-B,
# name: Ian,
# email: ian.203631a0-b@gmail.com,
# interests: ["Startups", "Travel"],
# last_updated: 2025-03-26 06:46:15
#
# 2. Oscar:
# id: 5,
# customer_id: EDD38E10-6,
# name: Oscar,
# email: oscar.edd38e10-6@gmail.com,
# interests: ["Automobile", "India", "Sports"],
# last_updated: 2025-03-26 06:46:15
#
# 3. Hannah:
# id: 6,
# customer_id: 4770B814-2,
# name: Hannah,
# email: hannah.4770b814-2@gmail.com,
# interests: ["Entertainment", "Business", "Technology"],
# last_updated: 2025-03-26 06:46:15
#
# 4. Ian:
# id: 13,
# customer_id: AEE37571-7,
# name: Ian,
# email: ian.aee37571-7@gmail.com,
# interests: ["Entertainment", "Automobile", "Startups"],
# last_updated: 2025-03-26 06:46:15
#
# Final Answer: The Ian, Hannah, and Oscar records were last updated on the following dates:
# - Ian (id 2): 2025-03-26 06:46:15
# - Ian (id 13): 2025-03-26 06:46:15
# - Oscar: 2025-03-26 06:46:15
# - Hannah: 2025-03-26 06:46:15
#
# > Finished chain.
# Result: The Ian, Hannah, and Oscar records were last updated on the following dates:
# - Ian (id 2): 2025-03-26 06:46:15
# - Ian (id 13): 2025-03-26 06:46:15
# - Oscar: 2025-03-26 06:46:15
# - Hannah: 2025-03-26 06:46:15
# --------------------------------------------------

# %% [markdown]
# ##  Retrieve the top 3 latest news based on the customer’s interest and Generate a summary of each resul

# %% [markdown]
# ## Get latest 3 news and its summary for oscar.edd38e10-6@gmail.com interest

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-summary
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDoscar.edd38e10-6@gmail.com
# Enter the number of URLs required3
#  'oscar.edd38e10-6@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersIt seems like there's only one table in the database, which is "customers". I should query the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */It seems like the "customers" table has a column named "interests" which might be relevant to the question about "interset". However, the question has a typo and is trying to select "interset" which does not exist in the table. Also, the question has a specific email address, so I should query the "customers" table with the given email address.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'oscar.edd38e10-6@gmail.com' )SELECT interests FROM customers WHERE email = 'oscar.edd38e10-6@gmail.com'The query checker suggests a correction to the query, which is to replace "IN" with "=" since we are only checking one email address.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'oscar.edd38e10-6@gmail.com'[('["Automobile", "India", "Sports"]',)]I now know the final answer
# Final Answer: ["Automobile", "India", "Sports"]
#
# > Finished chain.
# Raw Result: ["Automobile", "India", "Sports"]
# <class 'str'>
# Here are 3-5 trustworthy news URLs relevant to 'Automobile' published after December 31, 2024:
#
# * https://www.reuters.com/ (not available, as the exact URL is not provided)
# * https://www.nytimes.com/ (not available, as the exact URL is not provided)
# * No exact URLs are provided, however based on the given text the following can be constructed:
#  https://www.reuters.com/article/us-autos-news
# * https://www.theguardian.com/ (not available, as the exact URL is not provided)
# * No exact URLs are provided, however based on the given text the following can be constructed:
#  https://www.nytimes.com/2025/05/13/business/chinese-drivers-electric-vehicles.html
#
# Note: The exact URLs are not provided in the search results. The above URLs are constructed based on the given text and may not be the actual URLs.
#
# However, one possible URL is
# https://www.nytimes.com/2025/05/13/business/chinese-drivers-electric-vehicles.html
#
# Also
# https://www.reuters.com/article/us-autos-news
#
# Please note that these URLs may not work as they are constructed based on the given text.
#
# One more possible URL is
# https://www.theguardian.com/business/2025/sep/02/jlr-suppliers-face-bankruptcy-due-to-hack-crisis
#
# Please note that the above URLs may not work.
#
# One more
# https://www.reuters.com/business/autos-transportation/audi-poised-take-over-sauber-rises-f1-standings
#
# Please verify before using.
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Automobile' published after December 31, 2024:
#
# * https://www.reuters.com/ (not available, as the exact URL is not provided)
# * https://www.nytimes.com/ (not available, as the exact URL is not provided)
# * No exact URLs are provided, however based on the given text the following can be constructed:
#  https://www.reuters.com/article/us-autos-news
# * https://www.theguardian.com/ (not available, as the exact URL is not provided)
# * No exact URLs are provided, however based on the given text the following can be constructed:
#  https://www.nytimes.com/2025/05/13/business/chinese-drivers-electric-vehicles.html
#
# Note: The exact URLs are not provided in the search results. The above URLs are constructed based on the given text and may not be the actual URLs.
#
# However, one possible URL is
# https://www.nytimes.com/2025/05/13/business/chinese-drivers-electric-vehicles.html
#
# Also
# https://www.reuters.com/article/us-autos-news
#
# Please note that these URLs may not work as they are constructed based on the given text.
#
# One more possible URL is
# https://www.theguardian.com/business/2025/sep/02/jlr-suppliers-face-bankruptcy-due-to-hack-crisis
#
# Please note that the above URLs may not work.
#
# One more
# https://www.reuters.com/business/autos-transportation/audi-poised-take-over-sauber-rises-f1-standings
#
# Please verify before using.
# Here are 3-5 trustworthy news URLs relevant to 'India' published after December 31, 2024:
#
# * https://www.reuters.com/ (not a specific article, but a recent indicator of Reuters coverage)
# * https://www.nytimes.com/ (no specific article found, but NYT is a credible source)
# * https://www.theguardian.com/world/2025/jul/23/india-floods-northern-india (article about floods in Northern India)
# * https://www.bbc.com/news/ (no specific article found, but BBC is a credible source)
# * https://apnews.com/article/india-eu-trade-deal-7c5e4f3e4157e735f2e5c2e5d844f2d5 (article about India-EU trade deal)
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'India' published after December 31, 2024:
#
# * https://www.reuters.com/ (not a specific article, but a recent indicator of Reuters coverage)
# * https://www.nytimes.com/ (no specific article found, but NYT is a credible source)
# * https://www.theguardian.com/world/2025/jul/23/india-floods-northern-india (article about floods in Northern India)
# * https://www.bbc.com/news/ (no specific article found, but BBC is a credible source)
# * https://apnews.com/article/india-eu-trade-deal-7c5e4f3e4157e735f2e5c2e5d844f2d5 (article about India-EU trade deal)
# https://www.bbc.com/sport/live/world-athletics-championships-2025
# https://www.reuters.com/sports
# https://apnews.com/hub/sports
# https://www.nytimes.com/section/sports
# https://www.theguardian.com/sport
#  Complete LLM response: https://www.bbc.com/sport/live/world-athletics-championships-2025
# https://www.reuters.com/sports
# https://apnews.com/hub/sports
# https://www.nytimes.com/section/sports
# https://www.theguardian.com/sport
# Filtered news URLs for oscar.edd38e10-6@gmail.com:{'Automobile': ['https://www.reuters.com/', 'https://www.nytimes.com/', 'https://www.reuters.com/article/us-autos-news'], 'India': ['https://www.reuters.com/', 'https://www.nytimes.com/', 'https://www.theguardian.com/world/2025/jul/23/india-floods-northern-india'], 'Sports': ['https://www.bbc.com/sport/live/world-athletics-championships-2025', 'https://www.reuters.com/sports', 'https://apnews.com/hub/sports']}
# Title: Global Automotive Industry Shifts Towards Electric Vehicles
#
# Key Points: Major automakers are investing heavily in electric vehicle (EV) technology, governments are implementing stricter emissions regulations, and EV sales are expected to surge in the coming years, with many countries aiming to ban internal combustion engines by 2030-2040.
#
# Source: Reuters
#
# Date: March 10, 2024 (latest available)
#
# Summary: The global automotive industry is undergoing a significant transformation as companies like General Motors, Volkswagen, and Toyota transition towards electric vehicles, driven by growing demand, government incentives, and environmental concerns, with the EV market projected to reach $1.4 trillion by 2027. The shift is expected to create new opportunities for companies and jobs in the EV sector. Many countries are also investing in EV charging infrastructure to support the growing number of electric vehicles on the road. As the industry continues to evolve, traditional automakers are facing increased competition from new entrants and tech companies.
#
# URL: https://www.reuters.com/business/autos-transportation/
#  Complete LLM response: Title: Global Automotive Industry Shifts Towards Electric Vehicles
#
# Key Points: Major automakers are investing heavily in electric vehicle (EV) technology, governments are implementing stricter emissions regulations, and EV sales are expected to surge in the coming years, with many countries aiming to ban internal combustion engines by 2030-2040.
#
# Source: Reuters
#
# Date: March 10, 2024 (latest available)
#
# Summary: The global automotive industry is undergoing a significant transformation as companies like General Motors, Volkswagen, and Toyota transition towards electric vehicles, driven by growing demand, government incentives, and environmental concerns, with the EV market projected to reach $1.4 trillion by 2027. The shift is expected to create new opportunities for companies and jobs in the EV sector. Many countries are also investing in EV charging infrastructure to support the growing number of electric vehicles on the road. As the industry continues to evolve, traditional automakers are facing increased competition from new entrants and tech companies.
#
# URL: https://www.reuters.com/business/autos-transportation/
# Title: Electric Vehicles Gain Momentum as Governments Set Targets
#
# Key Points: The US and European governments have set targets to increase electric vehicle adoption, major automakers are investing heavily in EV technology, and battery costs are decreasing rapidly, making EVs more competitive with gas-powered cars.
#
# Source: The New York Times
#
# Date: September 13, 2024 (Please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The push for electric vehicles is gaining momentum as governments around the world set targets to phase out gas-powered cars, with many major automakers investing in EV technology and battery costs decreasing, making electric vehicles a more viable option for consumers, which could significantly impact the automobile industry in the coming years.
#
# URL: https://www.nytimes.com/
#  Complete LLM response: Title: Electric Vehicles Gain Momentum as Governments Set Targets
#
# Key Points: The US and European governments have set targets to increase electric vehicle adoption, major automakers are investing heavily in EV technology, and battery costs are decreasing rapidly, making EVs more competitive with gas-powered cars.
#
# Source: The New York Times
#
# Date: September 13, 2024 (Please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The push for electric vehicles is gaining momentum as governments around the world set targets to phase out gas-powered cars, with many major automakers investing in EV technology and battery costs decreasing, making electric vehicles a more viable option for consumers, which could significantly impact the automobile industry in the coming years.
#
# URL: https://www.nytimes.com/
# Title: Latest Automotive News
#
# Key Points: The global automotive industry is shifting towards electric vehicles, with many manufacturers investing heavily in EV technology, autonomous driving, and vehicle connectivity. Major automakers such as General Motors, Ford, and Volkswagen are leading the charge in EV adoption. The industry is also experiencing significant changes due to the COVID-19 pandemic and global supply chain disruptions. Additionally, governments are implementing stricter emissions regulations, driving the demand for eco-friendly vehicles.
#
# Source: Reuters
#
# Date: The information is current up to 2023, but the exact date may vary depending on the specific article.
#
# Summary: The automotive industry is undergoing significant transformations with the rise of electric vehicles, autonomous driving, and vehicle connectivity, driven by investments from major manufacturers and government regulations. The industry is also navigating challenges such as global supply chain disruptions and the COVID-19 pandemic. As the industry continues to evolve, manufacturers are adapting to changing consumer demands and regulatory requirements. The shift towards eco-friendly vehicles is expected to continue, with many countries implementing stricter emissions regulations. The future of the automotive industry will be shaped by these factors, leading to a more sustainable and technologically advanced sector.
#
# URL: https://www.reuters.com/article/us-autos-news
#  Complete LLM response: Title: Latest Automotive News
#
# Key Points: The global automotive industry is shifting towards electric vehicles, with many manufacturers investing heavily in EV technology, autonomous driving, and vehicle connectivity. Major automakers such as General Motors, Ford, and Volkswagen are leading the charge in EV adoption. The industry is also experiencing significant changes due to the COVID-19 pandemic and global supply chain disruptions. Additionally, governments are implementing stricter emissions regulations, driving the demand for eco-friendly vehicles.
#
# Source: Reuters
#
# Date: The information is current up to 2023, but the exact date may vary depending on the specific article.
#
# Summary: The automotive industry is undergoing significant transformations with the rise of electric vehicles, autonomous driving, and vehicle connectivity, driven by investments from major manufacturers and government regulations. The industry is also navigating challenges such as global supply chain disruptions and the COVID-19 pandemic. As the industry continues to evolve, manufacturers are adapting to changing consumer demands and regulatory requirements. The shift towards eco-friendly vehicles is expected to continue, with many countries implementing stricter emissions regulations. The future of the automotive industry will be shaped by these factors, leading to a more sustainable and technologically advanced sector.
#
# URL: https://www.reuters.com/article/us-autos-news
# --------------------------------------------------
# Summary for Automobile:
#
#  Relevant Latest news on Automobile
#
# Title: Global Automotive Industry Shifts Towards Electric Vehicles
#
# Key Points: Major automakers are investing heavily in electric vehicle (EV) technology, governments are implementing stricter emissions regulations, and EV sales are expected to surge in the coming years, with many countries aiming to ban internal combustion engines by 2030-2040.
#
# Source: Reuters
#
# Date: March 10, 2024 (latest available)
#
# Summary: The global automotive industry is undergoing a significant transformation as companies like General Motors, Volkswagen, and Toyota transition towards electric vehicles, driven by growing demand, government incentives, and environmental concerns, with the EV market projected to reach $1.4 trillion by 2027. The shift is expected to create new opportunities for companies and jobs in the EV sector. Many countries are also investing in EV charging infrastructure to support the growing number of electric vehicles on the road. As the industry continues to evolve, traditional automakers are facing increased competition from new entrants and tech companies.
#
# URL: https://www.reuters.com/business/autos-transportation/
#
#
#
# Title: Electric Vehicles Gain Momentum as Governments Set Targets
#
# Key Points: The US and European governments have set targets to increase electric vehicle adoption, major automakers are investing heavily in EV technology, and battery costs are decreasing rapidly, making EVs more competitive with gas-powered cars.
#
# Source: The New York Times
#
# Date: September 13, 2024 (Please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The push for electric vehicles is gaining momentum as governments around the world set targets to phase out gas-powered cars, with many major automakers investing in EV technology and battery costs decreasing, making electric vehicles a more viable option for consumers, which could significantly impact the automobile industry in the coming years.
#
# URL: https://www.nytimes.com/
#
#
#
# Title: Latest Automotive News
#
# Key Points: The global automotive industry is shifting towards electric vehicles, with many manufacturers investing heavily in EV technology, autonomous driving, and vehicle connectivity. Major automakers such as General Motors, Ford, and Volkswagen are leading the charge in EV adoption. The industry is also experiencing significant changes due to the COVID-19 pandemic and global supply chain disruptions. Additionally, governments are implementing stricter emissions regulations, driving the demand for eco-friendly vehicles.
#
# Source: Reuters
#
# Date: The information is current up to 2023, but the exact date may vary depending on the specific article.
#
# Summary: The automotive industry is undergoing significant transformations with the rise of electric vehicles, autonomous driving, and vehicle connectivity, driven by investments from major manufacturers and government regulations. The industry is also navigating challenges such as global supply chain disruptions and the COVID-19 pandemic. As the industry continues to evolve, manufacturers are adapting to changing consumer demands and regulatory requirements. The shift towards eco-friendly vehicles is expected to continue, with many countries implementing stricter emissions regulations. The future of the automotive industry will be shaped by these factors, leading to a more sustainable and technologically advanced sector.
#
# URL: https://www.reuters.com/article/us-autos-news

# %% [markdown]
# ## Get latest 3 news and its summary for emma.a88fec03-c@gmail.com interest

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-summary
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDemma.a88fec03-c@gmail.com
# Enter the number of URLs required3
#  'emma.a88fec03-c@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersNow that I have the list of tables, I can see that there is a table named "customers". I should query the schema of this table to see what columns are available.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */Now that I have the schema of the "customers" table, I can see that it has a column named "interests" which seems to be related to the input question. However, the input question is asking for "interset" which is not a valid column in the "customers" table. I should query the schema again to see if there are any other tables that might have a column named "interset". But before that, I should check if the email provided in the input question exists in the "customers" table.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'emma.a88fec03-c@gmail.com' )SELECT interests FROM customers WHERE email = 'emma.a88fec03-c@gmail.com'The query checker suggests that the query is correct, but it doesn't tell us if the email exists in the table. We should go ahead and execute this query to see if we get any results.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'emma.a88fec03-c@gmail.com'[('["Technology", "Automobile"]',)]The query returned a result, which means the email exists in the table. However, the input question asked for "interset" which is not a valid column in the "customers" table. It seems like there might be a typo in the input question and it should be "interests" instead.
#
# Thought: I now know the final answer
# Final Answer: ["Technology", "Automobile"]
#
# > Finished chain.
# Raw Result: ["Technology", "Automobile"]
# <class 'str'>
# Here are 3-5 trustworthy news URLs relevant to 'Technology' published after December 31, 2024:
#
# * https://www.bbc.com/news/science-and-environment-65931141 (not available, so using the given date)
# * https://www.theguardian.com/technology/2025/sep/03/
# * https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html (not available, so using the given date)
# * https://www.reuters.com/technology-news/article/us-tech-gadgets-idUSKBN2TT1D9 (not available, so using the given date)
# * https://apnews.com/article/technology-business-artificial-intelligence-21b7e2e5f2e54e6db1e5e2e5f2e54e61 (not available, so using the given date)
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Technology' published after December 31, 2024:
#
# * https://www.bbc.com/news/science-and-environment-65931141 (not available, so using the given date)
# * https://www.theguardian.com/technology/2025/sep/03/
# * https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html (not available, so using the given date)
# * https://www.reuters.com/technology-news/article/us-tech-gadgets-idUSKBN2TT1D9 (not available, so using the given date)
# * https://apnews.com/article/technology-business-artificial-intelligence-21b7e2e5f2e54e6db1e5e2e5f2e54e61 (not available, so using the given date)
# Here are 3-5 trustworthy news URLs relevant to 'Automobile' published after December 31, 2024:
#
# * https://www.nytimes.com/2025/09/02/business/ford-tariffs-profit.html
# * https://www.reuters.com/business/autos-transportation/uk-car-production-hits-lowest-level-since-1950s-2025-08-12/
# * https://www.bbc.com/news/business-64411115
# * https://apnews.com/article/business-technology-automotive-technology-tesla-inc-20250821
# * https://www.theguardian.com/business/2025/sep/05/munich-auto-show-european-carmakers
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Automobile' published after December 31, 2024:
#
# * https://www.nytimes.com/2025/09/02/business/ford-tariffs-profit.html
# * https://www.reuters.com/business/autos-transportation/uk-car-production-hits-lowest-level-since-1950s-2025-08-12/
# * https://www.bbc.com/news/business-64411115
# * https://apnews.com/article/business-technology-automotive-technology-tesla-inc-20250821
# * https://www.theguardian.com/business/2025/sep/05/munich-auto-show-european-carmakers
# Filtered news URLs for emma.a88fec03-c@gmail.com:{'Technology': ['https://www.bbc.com/news/science-and-environment-65931141', 'https://www.theguardian.com/technology/2025/sep/03/', 'https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html'], 'Automobile': ['https://www.nytimes.com/2025/09/02/business/ford-tariffs-profit.html', 'https://www.reuters.com/business/autos-transportation/uk-car-production-hits-lowest-level-since-1950s-2025-08-12/', 'https://www.bbc.com/news/business-64411115']}
# Title: NASA's SpaceX Crew-5 Mission
#
# Key Points: NASA's SpaceX Crew-5 mission has successfully launched, carrying four astronauts to the International Space Station, the mission will conduct over 200 scientific experiments, the crew will spend approximately 5 months on the space station, and the mission marks the fifth operational crew rotation flight on a SpaceX Crew Dragon spacecraft.
#
# Source: BBC News
#
# Date: The article was accessed on the current date, but the actual date of the article is not specified, however, the news is recent.
#
# Summary: The latest news from the BBC highlights the successful launch of NASA's SpaceX Crew-5 mission, which will enable the crew to conduct various scientific experiments and spend several months on the International Space Station, showcasing significant advancements in space technology and collaboration between NASA and SpaceX.
#
# URL: https://www.bbc.com/news/science-and-environment-65931141
#  Complete LLM response: Title: NASA's SpaceX Crew-5 Mission
#
# Key Points: NASA's SpaceX Crew-5 mission has successfully launched, carrying four astronauts to the International Space Station, the mission will conduct over 200 scientific experiments, the crew will spend approximately 5 months on the space station, and the mission marks the fifth operational crew rotation flight on a SpaceX Crew Dragon spacecraft.
#
# Source: BBC News
#
# Date: The article was accessed on the current date, but the actual date of the article is not specified, however, the news is recent.
#
# Summary: The latest news from the BBC highlights the successful launch of NASA's SpaceX Crew-5 mission, which will enable the crew to conduct various scientific experiments and spend several months on the International Space Station, showcasing significant advancements in space technology and collaboration between NASA and SpaceX.
#
# URL: https://www.bbc.com/news/science-and-environment-65931141
# Title: Latest Technology News
#
# Key Points: Unfortunately, I'm a large language model, I don't have have access to real-time information and the provided URL is not accessible. However, I can suggest some general information about technology news.
# Key points typically include new gadget releases, advancements in artificial intelligence, and cybersecurity updates.
#
# Source: The Guardian
#
# Date: September 3, 2025
#
# Summary: The latest technology news typically covers a wide range of topics including new smartphone releases, emerging trends in tech, and innovations in the field of artificial intelligence. However, without access to the specific URL, I'm unable to provide more detailed information. Technology news often has a significant impact on our daily lives, from the way we communicate to the way we work. As technology continues to evolve, we can expect to see new and exciting developments in the coming years.
#
# URL: https://www.theguardian.com/technology/2025/sep/03/
#  Complete LLM response: Title: Latest Technology News
#
# Key Points: Unfortunately, I'm a large language model, I don't have have access to real-time information and the provided URL is not accessible. However, I can suggest some general information about technology news.
# Key points typically include new gadget releases, advancements in artificial intelligence, and cybersecurity updates.
#
# Source: The Guardian
#
# Date: September 3, 2025
#
# Summary: The latest technology news typically covers a wide range of topics including new smartphone releases, emerging trends in tech, and innovations in the field of artificial intelligence. However, without access to the specific URL, I'm unable to provide more detailed information. Technology news often has a significant impact on our daily lives, from the way we communicate to the way we work. As technology continues to evolve, we can expect to see new and exciting developments in the coming years.
#
# URL: https://www.theguardian.com/technology/2025/sep/03/
# Title: Computer Science Graduates Face Increasing Job Opportunities
#
# Key Points: The demand for computer science graduates is on the rise, tech companies are expanding their hiring, and emerging technologies like AI and cybersecurity are driving job growth.
#
# Source: The New York Times
#
# Date: September 1, 2025
#
# Summary: According to a recent report, computer science graduates are experiencing increased job opportunities due to the growing demand for tech talent. The expansion of tech companies and the emergence of new technologies such as artificial intelligence and cybersecurity are driving this trend. As a result, computer science graduates are in high demand, with many securing high-paying jobs immediately after graduation. The report highlights the relevance of computer science education in today's technology-driven job market.
#
# URL: https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html
#  Complete LLM response: Title: Computer Science Graduates Face Increasing Job Opportunities
#
# Key Points: The demand for computer science graduates is on the rise, tech companies are expanding their hiring, and emerging technologies like AI and cybersecurity are driving job growth.
#
# Source: The New York Times
#
# Date: September 1, 2025
#
# Summary: According to a recent report, computer science graduates are experiencing increased job opportunities due to the growing demand for tech talent. The expansion of tech companies and the emergence of new technologies such as artificial intelligence and cybersecurity are driving this trend. As a result, computer science graduates are in high demand, with many securing high-paying jobs immediately after graduation. The report highlights the relevance of computer science education in today's technology-driven job market.
#
# URL: https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html
# --------------------------------------------------
# Summary for Technology:
#
#  Relevant Latest news on Technology
#
# Title: NASA's SpaceX Crew-5 Mission
#
# Key Points: NASA's SpaceX Crew-5 mission has successfully launched, carrying four astronauts to the International Space Station, the mission will conduct over 200 scientific experiments, the crew will spend approximately 5 months on the space station, and the mission marks the fifth operational crew rotation flight on a SpaceX Crew Dragon spacecraft.
#
# Source: BBC News
#
# Date: The article was accessed on the current date, but the actual date of the article is not specified, however, the news is recent.
#
# Summary: The latest news from the BBC highlights the successful launch of NASA's SpaceX Crew-5 mission, which will enable the crew to conduct various scientific experiments and spend several months on the International Space Station, showcasing significant advancements in space technology and collaboration between NASA and SpaceX.
#
# URL: https://www.bbc.com/news/science-and-environment-65931141
#
#
#
# Title: Latest Technology News
#
# Key Points: Unfortunately, I'm a large language model, I don't have have access to real-time information and the provided URL is not accessible. However, I can suggest some general information about technology news.
# Key points typically include new gadget releases, advancements in artificial intelligence, and cybersecurity updates.
#
# Source: The Guardian
#
# Date: September 3, 2025
#
# Summary: The latest technology news typically covers a wide range of topics including new smartphone releases, emerging trends in tech, and innovations in the field of artificial intelligence. However, without access to the specific URL, I'm unable to provide more detailed information. Technology news often has a significant impact on our daily lives, from the way we communicate to the way we work. As technology continues to evolve, we can expect to see new and exciting developments in the coming years.
#
# URL: https://www.theguardian.com/technology/2025/sep/03/
#
#
#
# Title: Computer Science Graduates Face Increasing Job Opportunities
#
# Key Points: The demand for computer science graduates is on the rise, tech companies are expanding their hiring, and emerging technologies like AI and cybersecurity are driving job growth.
#
# Source: The New York Times
#
# Date: September 1, 2025
#
# Summary: According to a recent report, computer science graduates are experiencing increased job opportunities due to the growing demand for tech talent. The expansion of tech companies and the emergence of new technologies such as artificial intelligence and cybersecurity are driving this trend. As a result, computer science graduates are in high demand, with many securing high-paying jobs immediately after graduation. The report highlights the relevance of computer science education in today's technology-driven job market.
#
# URL: https://www.nytimes.com/2025/09/01/technology/computer-science-graduates-jobs.html

# %% [markdown]
# ## Get latest 3 news and its summary for kevin.f8641860-7@gmail.com interest

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-summary
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDkevin.f8641860-7@gmail.com
# Enter the number of URLs required3
#  'kevin.f8641860-7@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersThat's a good start, but it seems like the table "users" is not in the database. The only table available is "customers".
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */It seems that the table "users" does not exist in the database, but the table "customers" has a column "email" that matches the email in the question. Also, the column name is "interests", not "interset". I should rewrite the query to match the correct table and column names.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'kevin.f8641860-7@gmail.com' )```sql
# SELECT interests
# FROM customers
# WHERE email = 'kevin.f8641860-7@gmail.com'
# ```The query checker suggests a slight modification to the query, which is to replace the IN operator with an equals operator since we're only checking one email address.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'kevin.f8641860-7@gmail.com'[('["Politics", "Startups", "Travel"]',)]I now know the final answer
# Final Answer: ["Politics", "Startups", "Travel"]
#
# > Finished chain.
# Raw Result: ["Politics", "Startups", "Travel"]
# <class 'str'>
# https://www.nytimes.com/section/us/politics
# https://www.theguardian.com/us-news/politics
# https://www.nytimes.com/topic/subject/united-states-politics-and-government
# https://www.reuters.com/news/us-politics
# https://www.bbc.com/news/politics
#  Complete LLM response: https://www.nytimes.com/section/us/politics
# https://www.theguardian.com/us-news/politics
# https://www.nytimes.com/topic/subject/united-states-politics-and-government
# https://www.reuters.com/news/us-politics
# https://www.bbc.com/news/politics
# https://www.nytimes.com/2025/02/20/business/tech-start-ups-ai.html
# https://www.nytimes.com/2025/03/10/business/inside-nyt/tech-start-ups-turn-to-ai.html
# https://www.reuters.com/business/deals-look-perplexity-ai-startup-secures-200-million-funding-2025-08-21
# https://www.nytimes.com/2025/08/22/business/ai-startups-large-language-models.html
# https://apnews.com/article/business-technology-artificial-intelligence-startups-ae092e5f5c1e4448a6f2e5fa6f5e9e95
#  Complete LLM response: https://www.nytimes.com/2025/02/20/business/tech-start-ups-ai.html
# https://www.nytimes.com/2025/03/10/business/inside-nyt/tech-start-ups-turn-to-ai.html
# https://www.reuters.com/business/deals-look-perplexity-ai-startup-secures-200-million-funding-2025-08-21
# https://www.nytimes.com/2025/08/22/business/ai-startups-large-language-models.html
# https://apnews.com/article/business-technology-artificial-intelligence-startups-ae092e5f5c1e4448a6f2e5fa6f5e9e95
# No relevant URLs found as the provided search results do not include specific news article URLs related to 'Travel' published after December 31, 2024.
#  Complete LLM response: No relevant URLs found as the provided search results do not include specific news article URLs related to 'Travel' published after December 31, 2024.
# Filtered news URLs for kevin.f8641860-7@gmail.com:{'Politics': ['https://www.nytimes.com/section/us/politics', 'https://www.theguardian.com/us-news/politics', 'https://www.nytimes.com/topic/subject/united-states-politics-and-government'], 'Startups': ['https://www.nytimes.com/2025/02/20/business/tech-start-ups-ai.html', 'https://www.nytimes.com/2025/03/10/business/inside-nyt/tech-start-ups-turn-to-ai.html', 'https://www.reuters.com/business/deals-look-perplexity-ai-startup-secures-200-million-funding-2025-08-21'], 'Travel': []}
# Title: Biden Administration Faces Challenges in Congress
#
# Key Points: The Biden administration is facing opposition from Republicans in Congress, particularly on issues like immigration and gun control, the President's approval ratings have been affected by high inflation and economic concerns, Democrats are trying to pass legislation on voting rights and climate change, and the midterm elections are approaching.
#
# Source: The New York Times
#
# Date: September 13, 2024 (please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The Biden administration is navigating a complex political landscape, with challenges from Congress and concerns about the economy and inflation, as the President and Democrats try to advance their legislative agenda and prepare for the upcoming midterm elections, the administration's ability to pass key legislation and maintain public support will be crucial in the coming months.
#
# URL: https://www.nytimes.com/section/us/politics
#  Complete LLM response: Title: Biden Administration Faces Challenges in Congress
#
# Key Points: The Biden administration is facing opposition from Republicans in Congress, particularly on issues like immigration and gun control, the President's approval ratings have been affected by high inflation and economic concerns, Democrats are trying to pass legislation on voting rights and climate change, and the midterm elections are approaching.
#
# Source: The New York Times
#
# Date: September 13, 2024 (please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The Biden administration is navigating a complex political landscape, with challenges from Congress and concerns about the economy and inflation, as the President and Democrats try to advance their legislative agenda and prepare for the upcoming midterm elections, the administration's ability to pass key legislation and maintain public support will be crucial in the coming months.
#
# URL: https://www.nytimes.com/section/us/politics
# Title: US Politics Update
#
# Key Points: The latest news from US politics includes developments on the 2024 presidential election, ongoing congressional investigations, and updates on policy decisions from the Biden administration. Recent polls show a shift in voter sentiment, with implications for the upcoming election. Congressional leaders are navigating complex legislative agendas, including debates on healthcare and economic policy. The Biden administration is also addressing international relations and national security concerns.
#
# Source: The Guardian
#
# Date: September 13, 2024 (please note that the date may not reflect real-time as my knowledge cutoff is December 2023)
#
# Summary: The US political landscape is evolving with new developments in the 2024 presidential election, congressional investigations, and policy decisions from the Biden administration, all of which are shaping the country's future and its position on the global stage. The ongoing shifts in voter sentiment and the complex legislative agendas are crucial in understanding the current state of US politics. As the election approaches, these factors will continue to influence the political discourse. The Biden administration's policy decisions and international relations efforts are also significant in this context. Overall, the situation is dynamic, with multiple factors at play.
#
# URL: https://www.theguardian.com/us-news/politics
#  Complete LLM response: Title: US Politics Update
#
# Key Points: The latest news from US politics includes developments on the 2024 presidential election, ongoing congressional investigations, and updates on policy decisions from the Biden administration. Recent polls show a shift in voter sentiment, with implications for the upcoming election. Congressional leaders are navigating complex legislative agendas, including debates on healthcare and economic policy. The Biden administration is also addressing international relations and national security concerns.
#
# Source: The Guardian
#
# Date: September 13, 2024 (please note that the date may not reflect real-time as my knowledge cutoff is December 2023)
#
# Summary: The US political landscape is evolving with new developments in the 2024 presidential election, congressional investigations, and policy decisions from the Biden administration, all of which are shaping the country's future and its position on the global stage. The ongoing shifts in voter sentiment and the complex legislative agendas are crucial in understanding the current state of US politics. As the election approaches, these factors will continue to influence the political discourse. The Biden administration's policy decisions and international relations efforts are also significant in this context. Overall, the situation is dynamic, with multiple factors at play.
#
# URL: https://www.theguardian.com/us-news/politics
# Title: United States Politics and Government
#
# Key Points: The US government is addressing various political issues, including the debt ceiling, immigration reform, and election security. Recent news highlights the ongoing debate between Democrats and Republicans on key policy matters. The Biden administration is working to pass significant legislation, such as climate change and healthcare bills. The political landscape is also being shaped by upcoming elections and candidate announcements.
#
# Source: The New York Times
#
# Date: September 13, 2024 (note: the date may not reflect real-time as the knowledge cutoff is December 2023)
#
# Summary: The latest news in US politics revolves around critical policy debates, legislative efforts, and election preparations, showcasing the complex and dynamic nature of the country's political landscape. The ongoing discussions and negotiations between political parties are expected to have significant implications for the nation's future. As the political environment continues to evolve, key stakeholders are working to address pressing issues and shape the country's direction. The New York Times provides in-depth coverage of these developments, offering insights into the intricacies of US politics and government.
#
# URL: https://www.nytimes.com/topic/subject/united-states-politics-and-government
#  Complete LLM response: Title: United States Politics and Government
#
# Key Points: The US government is addressing various political issues, including the debt ceiling, immigration reform, and election security. Recent news highlights the ongoing debate between Democrats and Republicans on key policy matters. The Biden administration is working to pass significant legislation, such as climate change and healthcare bills. The political landscape is also being shaped by upcoming elections and candidate announcements.
#
# Source: The New York Times
#
# Date: September 13, 2024 (note: the date may not reflect real-time as the knowledge cutoff is December 2023)
#
# Summary: The latest news in US politics revolves around critical policy debates, legislative efforts, and election preparations, showcasing the complex and dynamic nature of the country's political landscape. The ongoing discussions and negotiations between political parties are expected to have significant implications for the nation's future. As the political environment continues to evolve, key stakeholders are working to address pressing issues and shape the country's direction. The New York Times provides in-depth coverage of these developments, offering insights into the intricacies of US politics and government.
#
# URL: https://www.nytimes.com/topic/subject/united-states-politics-and-government
# --------------------------------------------------
# Summary for Politics:
#
#  Relevant Latest news on Politics
#
# Title: Biden Administration Faces Challenges in Congress
#
# Key Points: The Biden administration is facing opposition from Republicans in Congress, particularly on issues like immigration and gun control, the President's approval ratings have been affected by high inflation and economic concerns, Democrats are trying to pass legislation on voting rights and climate change, and the midterm elections are approaching.
#
# Source: The New York Times
#
# Date: September 13, 2024 (please note that the date may not reflect real-time information as my knowledge cutoff is December 2023)
#
# Summary: The Biden administration is navigating a complex political landscape, with challenges from Congress and concerns about the economy and inflation, as the President and Democrats try to advance their legislative agenda and prepare for the upcoming midterm elections, the administration's ability to pass key legislation and maintain public support will be crucial in the coming months.
#
# URL: https://www.nytimes.com/section/us/politics
#
#
#
# Title: US Politics Update
#
# Key Points: The latest news from US politics includes developments on the 2024 presidential election, ongoing congressional investigations, and updates on policy decisions from the Biden administration. Recent polls show a shift in voter sentiment, with implications for the upcoming election. Congressional leaders are navigating complex legislative agendas, including debates on healthcare and economic policy. The Biden administration is also addressing international relations and national security concerns.
#
# Source: The Guardian
#
# Date: September 13, 2024 (please note that the date may not reflect real-time as my knowledge cutoff is December 2023)
#
# Summary: The US political landscape is evolving with new developments in the 2024 presidential election, congressional investigations, and policy decisions from the Biden administration, all of which are shaping the country's future and its position on the global stage. The ongoing shifts in voter sentiment and the complex legislative agendas are crucial in understanding the current state of US politics. As the election approaches, these factors will continue to influence the political discourse. The Biden administration's policy decisions and international relations efforts are also significant in this context. Overall, the situation is dynamic, with multiple factors at play.
#
# URL: https://www.theguardian.com/us-news/politics
#
#
#
# Title: United States Politics and Government
#
# Key Points: The US government is addressing various political issues, including the debt ceiling, immigration reform, and election security. Recent news highlights the ongoing debate between Democrats and Republicans on key policy matters. The Biden administration is working to pass significant legislation, such as climate change and healthcare bills. The political landscape is also being shaped by upcoming elections and candidate announcements.
#
# Source: The New York Times
#
# Date: September 13, 2024 (note: the date may not reflect real-time as the knowledge cutoff is December 2023)
#
# Summary: The latest news in US politics revolves around critical policy debates, legislative efforts, and election preparations, showcasing the complex and dynamic nature of the country's political landscape. The ongoing discussions and negotiations between political parties are expected to have significant implications for the nation's future. As the political environment continues to evolve, key stakeholders are working to address pressing issues and shape the country's direction. The New York Times provides in-depth coverage of these developments, offering insights into the intricacies of US politics and government.
#
# URL: https://www.nytimes.com/topic/subject/united-states-politics-and-government

# %% [markdown]
# ## Get latest 3 news and its summary for nora.c63fa237-e@gmail.com interest

# %%
# !export PYTHONWARNINGS="ignore"
# !python main.py --job get-summary
# Out:
# Base Path: /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main
# Enter your Email IDnora.c63fa237-e@gmail.com
# Enter the number of URLs required3
#  'nora.c63fa237-e@gmail.com'
# /content/drive/MyDrive/PGP_AI_ML_GREAT_LEARNING/11_Advance_GenAI_NLP/Final_Project/main/NewsFinder.py:85: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.agent.run(query)
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: customersI have the list of tables in the database, which is "customers". Now, I should query the schema of this table to see what columns are available and to check if the column "interset" and "email" exist in this table.
#
# Action: sql_db_schema
# Action Input: customers
# CREATE TABLE customers (
# 	id INTEGER,
# 	customer_id TEXT NOT NULL,
# 	name TEXT NOT NULL,
# 	email TEXT NOT NULL,
# 	interests TEXT NOT NULL,
# 	last_updated TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (id),
# 	UNIQUE (customer_id),
# 	UNIQUE (email)
# )
#
# /*
# 3 rows from customers table:
# id	customer_id	name	email	interests	last_updated
# 1	F8641860-7	Kevin	kevin.f8641860-7@gmail.com	["Politics", "Startups", "Travel"]	2025-03-26 06:46:15
# 2	203631A0-B	Ian	ian.203631a0-b@gmail.com	["Startups", "Travel"]	2025-03-26 06:46:15
# 3	D77D96F3-3	Julia	julia.d77d96f3-3@gmail.com	["India", "Automobile", "Business"]	2025-03-26 06:46:15
# */The schema of the "customers" table has been retrieved, and it appears that the column "interset" does not exist in this table. However, there is a column named "interests" which seems to be related to the intended query.
#
# Action: sql_db_query_checker
# Action Input: SELECT interests FROM customers WHERE email IN ( 'nora.c63fa237-e@gmail.com' )```sql
# SELECT interests
# FROM customers
# WHERE email = 'nora.c63fa237-e@gmail.com'
# ```The query has been checked and seems to be correct. However, since the original query used the "IN" operator with a single email, I will replace it with an "=" operator for simplicity.
#
# Action: sql_db_query
# Action Input: SELECT interests FROM customers WHERE email = 'nora.c63fa237-e@gmail.com'[('["Entertainment", "Business"]',)]I now know the final answer
# Final Answer: ["Entertainment", "Business"]
#
# > Finished chain.
# Raw Result: ["Entertainment", "Business"]
# <class 'str'>
# Here are 3-5 trustworthy news URLs relevant to 'Entertainment' published after December 31, 2024:
#
# * https://www.bbc.com/news/entertainment-arts-67234115 (Sep 2, 2025)
# * https://www.bbc.com/news/entertainment-arts-67345621 (Aug 29, 2025)
# * https://www.bbc.com/news/entertainment-arts-67323456 (Aug 28, 2025)
# * https://www.bbc.com/news/entertainment-arts-67123419 (Jul 20, 2025)
#  Complete LLM response: Here are 3-5 trustworthy news URLs relevant to 'Entertainment' published after December 31, 2024:
#
# * https://www.bbc.com/news/entertainment-arts-67234115 (Sep 2, 2025)
# * https://www.bbc.com/news/entertainment-arts-67345621 (Aug 29, 2025)
# * https://www.bbc.com/news/entertainment-arts-67323456 (Aug 28, 2025)
# * https://www.bbc.com/news/entertainment-arts-67123419 (Jul 20, 2025)
# Since there are no specific URLs provided in the search results, I'll assume you want me to generate some based on the text. Here are 3-5 trustworthy news URLs relevant to 'Business' that could be published after December 31, 2024:
#
# * https://www.nytimes.com/business/2025/01/02/economy.html
# * https://apnews.com/article/business-news-01022025
# * https://www.reuters.com/business/finance-and-markets/2025/01/03/
# * https://www.theguardian.com/business/2025/jan/04/
# * https://www.bbc.com/news/business-2025-01-05
#  Complete LLM response: Since there are no specific URLs provided in the search results, I'll assume you want me to generate some based on the text. Here are 3-5 trustworthy news URLs relevant to 'Business' that could be published after December 31, 2024:
#
# * https://www.nytimes.com/business/2025/01/02/economy.html
# * https://apnews.com/article/business-news-01022025
# * https://www.reuters.com/business/finance-and-markets/2025/01/03/
# * https://www.theguardian.com/business/2025/jan/04/
# * https://www.bbc.com/news/business-2025-01-05
# Filtered news URLs for nora.c63fa237-e@gmail.com:{'Entertainment': ['https://www.bbc.com/news/entertainment-arts-67234115', 'https://www.bbc.com/news/entertainment-arts-67345621', 'https://www.bbc.com/news/entertainment-arts-67323456'], 'Business': ['https://www.nytimes.com/business/2025/01/02/economy.html', 'https://apnews.com/article/business-news-01022025', 'https://www.reuters.com/business/finance-and-markets/2025/01/03/']}
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, Margot Robbie stars as Barbie, the film has received mixed reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the information is subject to change)
#
# Summary: The Barbie movie has achieved a historic opening weekend, shattering box office records and becoming the largest opening for a female-led film, with Margot Robbie starring as the iconic character, despite receiving mixed reviews from critics, the film's commercial success is a significant milestone in the entertainment industry.
#
# URL: https://www.bbc.com/news/entertainment-arts-67234115
#  Complete LLM response: Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, Margot Robbie stars as Barbie, the film has received mixed reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the information is subject to change)
#
# Summary: The Barbie movie has achieved a historic opening weekend, shattering box office records and becoming the largest opening for a female-led film, with Margot Robbie starring as the iconic character, despite receiving mixed reviews from critics, the film's commercial success is a significant milestone in the entertainment industry.
#
# URL: https://www.bbc.com/news/entertainment-arts-67234115
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155 million in the US, and over $340 million worldwide, Margot Robbie stars as Barbie, the film has received positive reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the news is subject to change)
#
# Summary: The Barbie movie has shattered box office records, with a massive opening weekend, making it the largest debut for a female-led film, the movie's success can be attributed to its star-studded cast, and positive reviews from critics, the film's commercial success is a significant milestone for the entertainment industry, particularly for female-led films.
#
# URL: https://www.bbc.com/news/entertainment-arts-67345621
#  Complete LLM response: Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155 million in the US, and over $340 million worldwide, Margot Robbie stars as Barbie, the film has received positive reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the news is subject to change)
#
# Summary: The Barbie movie has shattered box office records, with a massive opening weekend, making it the largest debut for a female-led film, the movie's success can be attributed to its star-studded cast, and positive reviews from critics, the film's commercial success is a significant milestone for the entertainment industry, particularly for female-led films.
#
# URL: https://www.bbc.com/news/entertainment-arts-67345621
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155m in the US, and $340m globally, Margot Robbie stars as Barbie, the film has received positive reviews.
#
# Source: BBC News
#
# Date: Currently unavailable due to the nature of the request, however the article is recent.
#
# Summary: The Barbie movie has achieved significant success at the box office, breaking records for a female-led film and receiving positive reviews, with Margot Robbie starring as the iconic character, the film's success is a notable milestone in the entertainment industry, the movie's global gross has surpassed expectations, cementing its place as a major cinematic event.
#
# URL: https://www.bbc.com/news/entertainment-arts-67323456
#  Complete LLM response: Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155m in the US, and $340m globally, Margot Robbie stars as Barbie, the film has received positive reviews.
#
# Source: BBC News
#
# Date: Currently unavailable due to the nature of the request, however the article is recent.
#
# Summary: The Barbie movie has achieved significant success at the box office, breaking records for a female-led film and receiving positive reviews, with Margot Robbie starring as the iconic character, the film's success is a notable milestone in the entertainment industry, the movie's global gross has surpassed expectations, cementing its place as a major cinematic event.
#
# URL: https://www.bbc.com/news/entertainment-arts-67323456
# --------------------------------------------------
# Summary for Entertainment:
#
#  Relevant Latest news on Entertainment
#
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, Margot Robbie stars as Barbie, the film has received mixed reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the information is subject to change)
#
# Summary: The Barbie movie has achieved a historic opening weekend, shattering box office records and becoming the largest opening for a female-led film, with Margot Robbie starring as the iconic character, despite receiving mixed reviews from critics, the film's commercial success is a significant milestone in the entertainment industry.
#
# URL: https://www.bbc.com/news/entertainment-arts-67234115
#
#
#
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155 million in the US, and over $340 million worldwide, Margot Robbie stars as Barbie, the film has received positive reviews from critics.
#
# Source: BBC News
#
# Date: Current (please note that the exact date may vary as the news is subject to change)
#
# Summary: The Barbie movie has shattered box office records, with a massive opening weekend, making it the largest debut for a female-led film, the movie's success can be attributed to its star-studded cast, and positive reviews from critics, the film's commercial success is a significant milestone for the entertainment industry, particularly for female-led films.
#
# URL: https://www.bbc.com/news/entertainment-arts-67345621
#
#
#
# Title: Barbie Movie Breaks Box Office Records
#
# Key Points: The Barbie movie has broken box office records, becoming the biggest opening weekend for a female-led film, the movie has grossed over $155m in the US, and $340m globally, Margot Robbie stars as Barbie, the film has received positive reviews.
#
# Source: BBC News
#
# Date: Currently unavailable due to the nature of the request, however the article is recent.
#
# Summary: The Barbie movie has achieved significant success at the box office, breaking records for a female-led film and receiving positive reviews, with Margot Robbie starring as the iconic character, the film's success is a notable milestone in the entertainment industry, the movie's global gross has surpassed expectations, cementing its place as a major cinematic event.
#
# URL: https://www.bbc.com/news/entertainment-arts-67323456

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. The application has been created with real time personalized news based on the user's interest
#
# 2. The news are retrieved from the well authozised and authenticated news platform like BBC news, Reuters, The Guardian etc.,  so it ensuring the news is very much authenticated
#
# 3. In the application the provision has been created to limit the no of URLs to be retrieved also the news summariser
#
# 4. Ensuring the latest news to be share in the prompting itself it was restricted or to retrive the news from 2025 year
#
# 5. currently using llama-3.3-70b-versatile APIkey from groq.com which is free version and limited to No. of tokens or API calls so we can opt for the enteriprise subscription and can be used other LLM models as well
#
# 6. Front end wrapped can also be create also hosted for centralized utilizations

# %% [markdown]
# # References
#
# 1. Great learning LMS and MLS session contents
# 2. Langchain documentation

# %%
# !pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (7.16.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nbconvert) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (2.19.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert) (5.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.7->nbconvert) (4.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from nbclient>=0.5.0->nbconvert) (7.4.9)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert) (4.25.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.27.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.17.0)

# %%
# !jupyter nbconvert --to html NewsFinder_version_1_0.ipynb
# Out:
# [NbConvertApp] Converting notebook NewsFinder_version_1_0.ipynb to html
# [NbConvertApp] Writing 501254 bytes to NewsFinder_version_1_0.html
